# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./Data/TestData.csv')
df.drop(columns='Unnamed: 0', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 39 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   vin                   100000 non-null  object
#  1   body_type             99527 non-null   object
#  2   city                  100000 non-null  object
#  3   city_fuel_economy     83964 non-null   float64
#  4   daysonmarket          100000 non-null  int64
#  5   dealer_zip            100000 non-null  int64
#  6   engine_cylinders      96929 non-null   object
#  7   engine_displacement   94897 non-null   float64
#  8   exterior_color        100000 non-null  object
#  9   frame_damaged         100000 non-null  bool
#  10  franchise_dealer      100000 non-null  bool
#  11  franchise_make        100000 non-null  object
#  12  fuel_tank_volume      100000 non-null  object
#  13  fuel_type             100000 non-null  object
#  14  has_accidents         100000 non-null  bool
#  15  highway_fuel_economy  100000 non-null  object
#  16  horsepower            100000 non-null  object
#  17  interior_color        100000 non-null  object
#  18  isCab                 100000 non-null  bool
#  19  is_new                100000 non-null  bool
#  20  latitude              100000 non-null  float64
#  21  listed_date           100000 non-null  object
#  22  listing_color         100000 non-null  object
#  23  longitude             100000 non-null  float64
#  24  make_name             100000 non-null  object
#  25  maximum_seating       100000 non-null  object
#  26  mileage               92682 non-null   float64
#  27  model_name            100000 non-null  object
#  28  owner_count           52912 non-null   float64
#  29  price                 100000 non-null  float64
#  30  salvage               100000 non-null  bool
#  31  seller_rating         100000 non-null  float64
#  32  sp_name               100000 non-null  object
#  33  theft_title           100000 non-null  bool
#  34  transmission          100000 non-null  object
#  35  transmission_display  100000 non-null  object
#  36  wheel_system          100000 non-null  object
#  37  wheel_system_display  100000 non-null  object
#  38  year                  100000 non-null  int64
# dtypes: bool(7), float64(8), int64(3), object(21)
# memory usage: 25.1+ MB

# %%
df['year'].value_counts().sort_values(ascending=True).plot(kind='barh', figsize=(10,10))
# Out:
# <Axes: >

# %%
df['body_type'].value_counts().plot(kind='bar', figsize=(10, 10))
# Out:
# <Axes: >

# %%
df.loc[df['horsepower'] == 'False', 'horsepower'] = np.NaN
df['horsepower'] = df['horsepower'].astype('float64')
df.loc[df['city_fuel_economy'] == 'False', 'city_fuel_economy'] = np.NaN
df.loc[df['engine_cylinders'] == 'False', 'engine_cylinders'] = np.NaN
df.loc[df['engine_displacement'] == 'False', 'engine_displacement'] = np.NaN
df.loc[df['body_type'] == 'False', 'body_type'] = np.NaN
df.loc[df['mileage'] == 0.0, 'mileage'] = np.NaN
df.loc[df['owner_count'] == 0.0, 'owner_count'] = np.NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 39 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   vin                   100000 non-null  object
#  1   body_type             99527 non-null   object
#  2   city                  100000 non-null  object
#  3   city_fuel_economy     83964 non-null   float64
#  4   daysonmarket          100000 non-null  int64
#  5   dealer_zip            100000 non-null  int64
#  6   engine_cylinders      96929 non-null   object
#  7   engine_displacement   94897 non-null   float64
#  8   exterior_color        100000 non-null  object
#  9   frame_damaged         100000 non-null  bool
#  10  franchise_dealer      100000 non-null  bool
#  11  franchise_make        100000 non-null  object
#  12  fuel_tank_volume      100000 non-null  object
#  13  fuel_type             100000 non-null  object
#  14  has_accidents         100000 non-null  bool
#  15  highway_fuel_economy  100000 non-null  object
#  16  horsepower            94897 non-null   float64
#  17  interior_color        100000 non-null  object
#  18  isCab                 100000 non-null  bool
#  19  is_new                100000 non-null  bool
#  20  latitude              100000 non-null  float64
#  21  listed_date           100000 non-null  object
#  22  listing_color         100000 non-null  object
#  23  longitude             100000 non-null  float64
#  24  make_name             100000 non-null  object
#  25  maximum_seating       100000 non-null  object
#  26  mileage               92682 non-null   float64
#  27  model_name            100000 non-null  object
#  28  owner_count           52912 non-null   float64
#  29  price                 100000 non-null  float64
#  30  salvage               100000 non-null  bool
#  31  seller_rating         100000 non-null  float64
#  32  sp_name               100000 non-null  object
#  33  theft_title           100000 non-null  bool
#  34  transmission          100000 non-null  object
#  35  transmission_display  100000 non-null  object
#  36  wheel_system          100000 non-null  object
#  37  wheel_system_display  100000 non-null  object
#  38  year                  100000 non-null  int64
# dtypes: bool(7), float64(9), int64(3), object(20)
# memory usage: 25.1+ MB

# %%
df.head()
# Out:
#                  vin        body_type          city  city_fuel_economy  \
# 0  1FM5K8HC4LGA13788  SUV / Crossover    Grandville               18.0
# 1  1C4RJEBT9DC539441  SUV / Crossover       Raleigh                NaN
# 2  JTMBK31V475028962  SUV / Crossover  Indianapolis               19.0
# 3  4T1G11AKXLU335390            Sedan        Durham               28.0
# 4  JH4KB16565C007356            Sedan       Raleigh               16.0
#
#    daysonmarket  dealer_zip engine_cylinders  engine_displacement  \
# 0           406       49418               V6               3000.0
# 1            48       27616              NaN               5700.0
# 2            26       46222               V6               3500.0
# 3           235       27707               I4               2500.0
# 4            36       27604               V6               3500.0
#
#   exterior_color  frame_damaged  ...    price salvage seller_rating  \
# 0    Agate Black          False  ...  59677.0   False      4.466667
# 1           Blue          False  ...  13500.0   False      3.555556
# 2          White          False  ...   7900.0   False      2.333333
# 3    Super White          False  ...  27324.0   False      4.312500
# 4           GOLD          False  ...   5900.0   False      4.571429
#
#                  sp_name  theft_title transmission  transmission_display  \
# 0     Borgman Ford Mazda        False            A             Automatic
# 1      Raleigh Pre-Owned        False            A             Automatic
# 2  California Auto Sales        False            A     5-Speed Automatic
# 3   Mark Jacobson Toyota        False            A     8-Speed Automatic
# 4    Brother Auto Sales         False            A             Automatic
#
#   wheel_system  wheel_system_display  year
# 0          AWD       All-Wheel Drive  2020
# 1          4X2                   4X2  2013
# 2          4WD      Four-Wheel Drive  2007
# 3          FWD     Front-Wheel Drive  2020
# 4          AWD       All-Wheel Drive  2005
#
# [5 rows x 39 columns]

# %%
suv_df = df[df['body_type'] == 'SUV / Crossover']

# %%
suv_df.to_csv('./Data/SUVData.csv')

# %%
# df.plot(kind='hist', x='seller_rating', y='price', figsize= (15,15))

x = df['seller_rating']
y = df['price']
plt.scatter(x, y)
plt.xlim(3,5)
plt.show()

# %%
df.head()
# Out:
#                  vin        body_type          city  city_fuel_economy  \
# 0  1FM5K8HC4LGA13788  SUV / Crossover    Grandville               18.0
# 1  1C4RJEBT9DC539441  SUV / Crossover       Raleigh                NaN
# 2  JTMBK31V475028962  SUV / Crossover  Indianapolis               19.0
# 3  4T1G11AKXLU335390            Sedan        Durham               28.0
# 4  JH4KB16565C007356            Sedan       Raleigh               16.0
#
#    daysonmarket  dealer_zip engine_cylinders  engine_displacement  \
# 0           406       49418               V6               3000.0
# 1            48       27616              NaN               5700.0
# 2            26       46222               V6               3500.0
# 3           235       27707               I4               2500.0
# 4            36       27604               V6               3500.0
#
#   exterior_color  frame_damaged  ...    price salvage seller_rating  \
# 0    Agate Black          False  ...  59677.0   False      4.466667
# 1           Blue          False  ...  13500.0   False      3.555556
# 2          White          False  ...   7900.0   False      2.333333
# 3    Super White          False  ...  27324.0   False      4.312500
# 4           GOLD          False  ...   5900.0   False      4.571429
#
#                  sp_name  theft_title transmission  transmission_display  \
# 0     Borgman Ford Mazda        False            A             Automatic
# 1      Raleigh Pre-Owned        False            A             Automatic
# 2  California Auto Sales        False            A     5-Speed Automatic
# 3   Mark Jacobson Toyota        False            A     8-Speed Automatic
# 4    Brother Auto Sales         False            A             Automatic
#
#   wheel_system  wheel_system_display  year
# 0          AWD       All-Wheel Drive  2020
# 1          4X2                   4X2  2013
# 2          4WD      Four-Wheel Drive  2007
# 3          FWD     Front-Wheel Drive  2020
# 4          AWD       All-Wheel Drive  2005
#
# [5 rows x 39 columns]

# %%
df['transmission'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='transmission'>

# %%
limited_df = df[df['price'] <= 200000]


plt.scatter(x=limited_df['price'], y=limited_df['mileage'])
plt.xlabel("Price")
plt.ylabel("Mileage")
plt.show()

# %%
import glob

# Create a pattern for the file names
pattern = 'Data/Filtered/data-*.csv'

# Use the glob module to get all the files matching the pattern
file_list = glob.glob(pattern)

# Read each file into a DataFrame and store them in a list
dfs = [pd.read_csv(file) for file in file_list]

# Concatenate all the DataFrames in the list into a single DataFrame
df = pd.concat(dfs, ignore_index=True)

# Now, 'df' contains data from all the CSV files
# Out:
# /var/folders/2j/qtkc2d3d6ld7y6mhr39mt2_w0000gn/T/ipykernel_41441/2934063356.py:10: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = [pd.read_csv(file) for file in file_list]
# /var/folders/2j/qtkc2d3d6ld7y6mhr39mt2_w0000gn/T/ipykernel_41441/2934063356.py:10: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = [pd.read_csv(file) for file in file_list]
# /var/folders/2j/qtkc2d3d6ld7y6mhr39mt2_w0000gn/T/ipykernel_41441/2934063356.py:10: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = [pd.read_csv(file) for file in file_list]
# /var/folders/2j/qtkc2d3d6ld7y6mhr39mt2_w0000gn/T/ipykernel_41441/2934063356.py:10: DtypeWarning: Columns (8,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = [pd.read_csv(file) for file in file_list]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2855638 entries, 0 to 2855652
# Data columns (total 40 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   Unnamed: 0            int64
#  1   vin                   object
#  2   body_type             object
#  3   city                  object
#  4   city_fuel_economy     object
#  5   daysonmarket          int64
#  6   dealer_zip            object
#  7   engine_cylinders      object
#  8   engine_displacement   object
#  9   exterior_color        object
#  10  frame_damaged         bool
#  11  franchise_dealer      bool
#  12  franchise_make        object
#  13  fuel_tank_volume      object
#  14  fuel_type             object
#  15  has_accidents         bool
#  16  highway_fuel_economy  object
#  17  horsepower            object
#  18  interior_color        object
#  19  isCab                 bool
#  20  is_new                bool
#  21  latitude              float64
#  22  listed_date           object
#  23  listing_color         object
#  24  longitude             float64
#  25  make_name             object
#  26  maximum_seating       object
#  27  mileage               float64
#  28  model_name            object
#  29  owner_count           float64
#  30  price                 float64
#  31  salvage               bool
#  32  seller_rating         float64
#  33  sp_name               object
#  34  theft_title           bool
#  35  transmission          object
#  36  transmission_display  object
#  37  wheel_system          object
#  38  wheel_system_display  object
#  39  year                  int64
# dtypes: bool(7), float64(6), int64(3), object(24)
# memory usage: 759.8+ MB

# %%
df = df[df['mileage'] <= 400000]

# %%
df.to_csv('Data/FullData.csv')

# %%
train_data_df = df[df['body_type'] == 'SUV / Crossover']
train_data_df.head()
# Out:
#    Unnamed: 0                vin        body_type          city  \
# 0           0  1FM5K8HC4LGA13788  SUV / Crossover    Grandville
# 1           1  1C4RJEBT9DC539441  SUV / Crossover       Raleigh
# 2           2  JTMBK31V475028962  SUV / Crossover  Indianapolis
# 5           5  5FNYF5H50MB002594  SUV / Crossover       Raleigh
# 9           9  2GNALBEK0G1114832  SUV / Crossover       Raleigh
#
#   city_fuel_economy  daysonmarket dealer_zip engine_cylinders  \
# 0              18.0           406      49418               V6
# 1             False            48      27616            False
# 2              19.0            26      46222               V6
# 5              20.0            25      27616               V6
# 9              22.0           428      27616               I4
#
#   engine_displacement         exterior_color  ...    price  salvage  \
# 0              3000.0            Agate Black  ...  59677.0    False
# 1              5700.0                   Blue  ...  13500.0    False
# 2              3500.0                  White  ...   7900.0    False
# 5              3500.0  Lunar Silver Metallic  ...  39480.0    False
# 9              2400.0                 Silver  ...  13998.0    False
#
#   seller_rating                sp_name theft_title  transmission  \
# 0      4.466667     Borgman Ford Mazda       False             A
# 1      3.555556      Raleigh Pre-Owned       False             A
# 2      2.333333  California Auto Sales       False             A
# 5      4.354839            Leith Honda       False             A
# 9      3.555556      Raleigh Pre-Owned       False             A
#
#   transmission_display wheel_system wheel_system_display  year
# 0            Automatic          AWD      All-Wheel Drive  2020
# 1            Automatic          4X2                  4X2  2013
# 2    5-Speed Automatic          4WD     Four-Wheel Drive  2007
# 5            Automatic          FWD    Front-Wheel Drive  2021
# 9            Automatic          FWD    Front-Wheel Drive  2016
#
# [5 rows x 40 columns]

# %%
train_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1343472 entries, 0 to 2855651
# Data columns (total 9 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   body_type      1343472 non-null  object
#  1   has_accidents  1343472 non-null  bool
#  2   make_name      1343472 non-null  object
#  3   mileage        1343472 non-null  float64
#  4   model_name     1343472 non-null  object
#  5   owner_count    1343472 non-null  float64
#  6   price          1343472 non-null  float64
#  7   transmission   1343472 non-null  object
#  8   year           1343472 non-null  int64
# dtypes: bool(1), float64(3), int64(1), object(4)
# memory usage: 93.5+ MB

# %%
# Limiting to columns users are going to enter
columns_users_wont_know = ['vin', 'seller_rating', 'sp_name', 'transmission_display', 'wheel_system_display', 'wheel_system', 'theft_title', 'maximum_seating', 'longitude',
                           'latitude', 'franchise_dealer', 'listed_date', 'dealer_zip', 'daysonmarket', 'engine_displacement', 'fuel_tank_volume', 'listing_color', 'highway_fuel_economy',
                           'isCab', 'fuel_type', 'is_new', 'horsepower', 'engine_cylinders', 'city_fuel_economy', 'interior_color', 'salvage', 'frame_damaged', 'exterior_color', 'city', 'franchise_make', 'Unnamed: 0']

# Color could come into play later but would be difficult to allow user to choose any color they want and not limited to only the colors we can see

train_data_df.drop(columns=columns_users_wont_know, axis=1, inplace=True)
# Out:
# /var/folders/2j/qtkc2d3d6ld7y6mhr39mt2_w0000gn/T/ipykernel_41441/1979979493.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data_df.drop(columns=columns_users_wont_know, axis=1, inplace=True)

# %%
train_data_df.to_csv('Data/ModelData/All_SUV_Data.csv')

# %%
train_data_df.loc[df['mileage'] == 0.0, 'mileage'] = np.NaN
train_data_df.loc[df['owner_count'] == 0.0, 'owner_count'] = np.NaN

# %%
suv_train_data = train_data_df.head(1000000)
suv_test_data = train_data_df.tail(300000)

# %%
suv_train_data.tail()
# Out:
#                body_type  has_accidents make_name  mileage  model_name  \
# 2115611  SUV / Crossover          False      Jeep  29395.0     Compass
# 2115613  SUV / Crossover          False      Jeep     10.0    Cherokee
# 2115616  SUV / Crossover          False     Dodge  18468.0     Journey
# 2115617  SUV / Crossover          False    Toyota      8.0  Highlander
# 2115618  SUV / Crossover          False     Buick      4.0     Enclave
#
#          owner_count    price transmission  year
# 2115611          1.0  21300.0            A  2020
# 2115613          NaN  19833.0            A  2020
# 2115616          1.0  16999.0            A  2018
# 2115617          NaN  44267.0            A  2020
# 2115618          NaN  39885.0            A  2020

# %%
suv_test_data.head()
# Out:
#                body_type  has_accidents make_name   mileage model_name  \
# 2213524  SUV / Crossover          False  Cadillac   25829.0        XT5
# 2213527  SUV / Crossover          False      Ford   27793.0   Explorer
# 2213529  SUV / Crossover          False       GMC  107403.0     Acadia
# 2213533  SUV / Crossover          False      Ford   84510.0     Escape
# 2213536  SUV / Crossover          False      Jeep   55860.0   Renegade
#
#          owner_count    price transmission  year
# 2213524          1.0  31495.0            A  2018
# 2213527          1.0  30714.0            A  2017
# 2213529          NaN  14922.0            A  2015
# 2213533          3.0  10988.0            A  2015
# 2213536          1.0  18900.0            A  2016

# %%
suv_test_data.to_csv('Data/ModelData/test_data.csv')
suv_train_data.to_csv('Data/ModelData/train_data.csv')

# %%
suv_test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 300000 entries, 2213524 to 2855651
# Data columns (total 9 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   body_type      300000 non-null  object
#  1   has_accidents  300000 non-null  bool
#  2   make_name      300000 non-null  object
#  3   mileage        270151 non-null  float64
#  4   model_name     300000 non-null  object
#  5   owner_count    140955 non-null  float64
#  6   price          300000 non-null  float64
#  7   transmission   300000 non-null  object
#  8   year           300000 non-null  int64
# dtypes: bool(1), float64(3), int64(1), object(4)
# memory usage: 20.9+ MB

# %%
suv_train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000000 entries, 0 to 2115618
# Data columns (total 9 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   body_type      1000000 non-null  object
#  1   has_accidents  1000000 non-null  bool
#  2   make_name      1000000 non-null  object
#  3   mileage        898649 non-null   float64
#  4   model_name     1000000 non-null  object
#  5   owner_count    466610 non-null   float64
#  6   price          1000000 non-null  float64
#  7   transmission   1000000 non-null  object
#  8   year           1000000 non-null  int64
# dtypes: bool(1), float64(3), int64(1), object(4)
# memory usage: 69.6+ MB
